# %% [markdown]
# <a href="https://colab.research.google.com/github/TillVollmer5/DSF-FS2022-Till-Vollmer/blob/main/Code_Niklaas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

from google.colab import drive
drive.mount('/content/drive', force_remount = True)
# Out:
# Mounted at /content/drive

# %%
db_df = pd.read_table('/content/drive/My Drive/Products.txt', header=0, error_bad_lines=False, delimiter='\t')
# Out:
# <ipython-input-20-abdd53499d61>:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   db_df = pd.read_table('/content/drive/My Drive/Products.txt', header=0, error_bad_lines=False, delimiter='\t')
# Skipping line 35475: expected 8 fields, saw 9
# Skipping line 35476: expected 8 fields, saw 9
# Skipping line 35477: expected 8 fields, saw 9

# %%
print(db_df)
# Out:
#        ApplNo  ProductNo                       Form                Strength  \
# 0           4          4  SOLUTION/DROPS;OPHTHALMIC                      1%
# 1         159          1                TABLET;ORAL                   500MG
# 2         552          1       INJECTABLE;INJECTION         20,000 UNITS/ML
# 3         552          2       INJECTABLE;INJECTION         40,000 UNITS/ML
# 4         552          3       INJECTABLE;INJECTION          5,000 UNITS/ML
# ...       ...        ...                        ...                     ...
# 46815  761345          1         SOLUTION;INJECTION                    12MG
# 46816  761349          1       INJECTABLE;INJECTION                   150MG
# 46817  761354          1       INJECTABLE;INJECTION                80MG/4ML
# 46818  761355          1       INJECTABLE;INJECTION  8MG(0.07ML;114.3MG/ML)
# 46819  761358          1       INJECTABLE;INJECTION                120MG/ML
#
# ...

# %%
count = 0
selected_rows_df = pd.DataFrame(columns=db_df.columns)

for i in range(46820):
  if db_df['Form'].iloc[i] == 'INJECTABLE;INJECTION':
    count += 1
    selected_rows_df = selected_rows_df.append(db_df.iloc[i])
  else:
    continue

print(count)
print(selected_rows_df)
# Out:
# Streaming output truncated to the last 5000 lines.
# <ipython-input-36-8f94b3340b9b>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   selected_rows_df = selected_rows_df.append(db_df.iloc[i])
# <ipython-input-36-8f94b3340b9b>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   selected_rows_df = selected_rows_df.append(db_df.iloc[i])
# <ipython-input-36-8f94b3340b9b>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   selected_rows_df = selected_rows_df.append(db_df.iloc[i])
# <ipython-input-36-8f94b3340b9b>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   selected_rows_df = selected_rows_df.append(db_df.iloc[i])
# ...

# %%
count_pn = 0
pn_df = pd.DataFrame(columns=db_df.columns)

for i in range(count):
  if selected_rows_df['ProductNo'].iloc[i] == 1:
    count_pn += 1
    pn_df = selected_rows_df.append(db_df.iloc[i])
  else:
    continue
# Out:
# Streaming output truncated to the last 5000 lines.
# <ipython-input-46-cf50db3f66ea>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pn_df = selected_rows_df.append(db_df.iloc[i])
# <ipython-input-46-cf50db3f66ea>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pn_df = selected_rows_df.append(db_df.iloc[i])
# <ipython-input-46-cf50db3f66ea>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pn_df = selected_rows_df.append(db_df.iloc[i])
# <ipython-input-46-cf50db3f66ea>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pn_df = selected_rows_df.append(db_df.iloc[i])
# ...

# %%
print(pn_df)
# Out:
#        ApplNo ProductNo                   Form  \
# 2         552         1   INJECTABLE;INJECTION
# 3         552         2   INJECTABLE;INJECTION
# 4         552         3   INJECTABLE;INJECTION
# 5         552         4   INJECTABLE;INJECTION
# 6         552         5   INJECTABLE;INJECTION
# ...       ...       ...                    ...
# 46816  761349         1   INJECTABLE;INJECTION
# 46817  761354         1   INJECTABLE;INJECTION
# 46818  761355         1   INJECTABLE;INJECTION
# 46819  761358         1   INJECTABLE;INJECTION
# 7280    22074         3  SOLUTION;SUBCUTANEOUS
#
#                                         Strength ReferenceDrug  \
# 2                                20,000 UNITS/ML             0
# 3                                40,000 UNITS/ML             0
# 4                                 5,000 UNITS/ML             0
# 5                                 1,000 UNITS/ML             0
# 6                                10,000 UNITS/ML             0
# ...
